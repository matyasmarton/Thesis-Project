# %%
# Import packages
import os
import cv2
import numpy as np
from PIL import Image

# %%
# Change directory where your images are
os.chdir(r"D:\Python\Film Face\train_test\ANGLE_ EXTENDED DATA2022")

# %%
pwd
# Out:
# 'D:\\Python\\Film Face\\train_test\\ANGLE_ EXTENDED DATA2022'

# %% [markdown]
# # Resize

# %%
# Variables store the path of the different folders
HIGH = os.listdir(r"D:\Python\Film Face\train_test\ANGLE_ EXTENDED DATA2022\HIGH")
MED = os.listdir(r"D:\Python\Film Face\train_test\ANGLE_ EXTENDED DATA2022\Med")
LOW = os.listdir(r"D:\Python\Film Face\train_test\ANGLE_ EXTENDED DATA2022\LOW")

CU = os.listdir(r"D:\Python\Film Face\Dataset Folders\train_test3200_thumbnail\CU")
MC = os.listdir(r"D:\Python\Film Face\Dataset Folders\train_test3200_thumbnail\MC")
ML = os.listdir(r"D:\Python\Film Face\Dataset Folders\train_test3200_thumbnail\ML")
L = os.listdir(r"D:\Python\Film Face\Dataset Folders\train_test3200_thumbnail\L")

# %%
# Change directory to the desired folder.  
os.chdir(r"D:\Python\Film Face\train_test\ANGLE_ EXTENDED DATA2022\LOW")
# Note: Evry time you wish to resize a set of images you have to change the path of the folder they are stored.

# %%
files = [CU,MC,ML,L]

# %%
import numpy as np
import cv2

# %%
#Flip images for dataaugmentation
for i in HIGH:
    img = cv2.imread(i,1)
    im = cv2.flip(img, 1)
    #print(size)
    #im = cv2.resize(img,size)
    cv2.imwrite('augmented '+i, im )
    try:
        os.remove(i)
    except: pass

# %%
img = cv2.imread(CU[0])

if img is None:
    print('Wrong path:', CU[0])
else:
    img = cv2.resize(img,size)
# Out:
# Wrong path: big-munich-Scene-0430-02.jpg

# %%
# Resize images 
for i in LOW:
    img = cv2.imread(i,1)
    width = 160
    height = 90
    size = (width,height)
    print(size)
    im = cv2.resize(img,size)
    cv2.imwrite('thumbnail '+i, im )
    try:
        os.remove(i)
    except: pass
# Out:
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# (160, 90)
# ...
